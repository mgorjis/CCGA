# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Utils import CreatePopRegimes,CreatePopTimes,sortgen,CrossoverRegimes,CrossoverTimes,MutationRegimes
import numpy as np
from Modeling import ModelIt, SolveTheta
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.hstack([2*np.ones([1,50]),3*np.ones([1,50]),6*np.ones([1,50])])+0.*np.random.rand(1,150)
K=3
C=2
T=150
model='K-means'
PopsizeTimes=50
PopsizeRegimes=50

# %%
plt.plot(x[0]);

# %%
PopTimes=[CreatePopTimes(C,T) for k in range(0,PopsizeTimes)]
PopRegimes=[CreatePopRegimes(K,C,T) for k in range(0,PopsizeRegimes)]

# %%
#Initialize
CostTimes=np.empty([PopsizeTimes])
for i in range(0,PopsizeTimes):
    pair=random.choice(PopRegimes)
    Theta,  CostTimes[i]=SolveTheta(PopTimes[i],pair,x[0],K=K,C=C,T=T, model=model)
    
CostRegimes=np.empty([PopsizeRegimes])
for i in range(0,PopsizeRegimes):
    pair=random.choice(PopTimes)
    Theta,  CostRegimes[i]=SolveTheta(pair,PopRegimes[i],x[0],K=K,C=C,T=T, model=model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2367b4e132a8> in <module>
#       3 for i in range(0,PopsizeTimes):
#       4     pair=random.choice(PopRegimes)
# ----> 5     Theta,  CostTimes[i]=SolveTheta(PopTimes[i],pair,x[0],K=K,C=C,T=T, model=model)
#       6
#       7 CostRegimes=np.empty([PopsizeRegimes])
#
# TypeError: SolveTheta() missing 1 required positional argument: 'u'

# %%
for i in range(0,1):
    #updata time population
    a=map(lambda m: SolveTheta(m,BestRegimes,x[0],K=K,C=C,T=T, model='K-means'),Times)
    b=list(a)
    CostTimes=[b[i][1] for i in list(range(0,PopsizeTimes))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3deb20adc171> in <module>()
#       1 for i in range(0,1):
#       2     #updata time population
# ----> 3     a=map(lambda m: SolveTheta(m,BestRegimes,x[0],K=K,C=C,T=T, model='K-means'),Times)
#       4     b=list(a)
#       5     CostTimes=[b[i][1] for i in list(range(0,PopsizeTimes))]
#
# NameError: name 'Times' is not defined

# %%
Theta,  Error=SolveTheta(a,b,x[0],K=K,C=C,T=T, model='K-means')

a=map(lambda m: SolveTheta(m,Regimes[1],x[0],K=K,C=C,T=T, model='K-means'),Times)
b=list(a)
[b[i][1] for i in list(range(0,PopsizeTimes))

# %%
b=list(a)

# %%
[b[i][1] for i in list(range(0,PopsizeTimes))]
# Out:
# [26.715708217117086,
#  97.302214508987021,
#  295.60881188691064,
#  93.539748033251797,
#  146.95231639762446,
#  280.95461179790851,
#  37.331033798148049,
#  132.65614920289124,
#  59.657302405740481,
#  253.84080328014181,
#  80.500989079367756,
#  290.88134819813143,
#  183.66190793673582,
#  88.844449560738624,
#  330.36866589244141,
#  114.81930654346377,
#  334.10117127417146,
#  55.829318242141419,
#  68.024208903047196,
#  31.431548203735105,
#  156.50475905833565,
#  66.00307939607859,
#  136.74599154643994,
#  242.00182290059786,
#  219.65725504524355,
#  181.98238973281758,
#  239.66970372648976,
#  260.40859875123431,
#  270.08681619718988,
#  158.09453088515858,
#  352.10963471886828,
#  407.81371141545418,
#  60.322767448381093,
#  136.73976303548656,
#  327.24011468892968,
#  180.84080811175971,
#  356.00622713614064,
#  225.09891881735152,
#  206.35076738561003,
#  68.728556589619103,
#  57.591453035582227,
#  208.91628211785283,
#  417.12778859938396,
# ...

# %%
b[0]
# Out:
# (array([[ 3.19878164,  2.2428923 ,  6.03988493]]), 26.715708217117086)

# %%
def adding(x,y):
    z=x+y
    a=z-y
    return z,a

# %%
# %timeit map(lambda x: adding(x,2), range(0,1000))
# Out:
# 1000000 loops, best of 3: 680 ns per loop

# %%
# %timeit [adding(x,2) for x in range(0,1000)]
# Out:
# 1000 loops, best of 3: 312 µs per loop

# %%
# %timeit list(map (adding,range(0,1000),list(2*np.ones([1,10])[0])))
# Out:
# The slowest run took 4.44 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 16.3 µs per loop

# %%
list(map (adding,range(0,1000),list(2*np.ones([1,10])[0])))
# Out:
# [(2.0, 0.0),
#  (3.0, 1.0),
#  (4.0, 2.0),
#  (5.0, 3.0),
#  (6.0, 4.0),
#  (7.0, 5.0),
#  (8.0, 6.0),
#  (9.0, 7.0),
#  (10.0, 8.0),
#  (11.0, 9.0)]
